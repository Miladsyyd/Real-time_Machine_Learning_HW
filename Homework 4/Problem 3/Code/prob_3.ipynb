# %%
import numpy as np
import tensorflow as tf
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input, Embedding, GRU, Dense, Attention, Lambda
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences

# Ensure eager execution
tf.config.run_functions_eagerly(True)

# Full DATASET
english_to_french = [
    ("I am cold", "J'ai froid"),
    ("You are tired", "Tu es fatigué"),
    ("He is hungry", "Il a faim"),
    ("She is happy", "Elle est heureuse"),
    ("We are friends", "Nous sommes amis"),
    ("They are students", "Ils sont étudiants"),
    ("The cat is sleeping", "Le chat dort"),
    ("The sun is shining", "Le soleil brille"),
    ("We love music", "Nous aimons la musique"),
    ("She speaks French fluently", "Elle parle français couramment"),
    ("He enjoys reading books", "Il aime lire des livres"),
    ("They play soccer every weekend", "Ils jouent au football chaque week-end"),
    ("The movie starts at 7 PM", "Le film commence à 19 heures"),
    ("She wears a red dress", "Elle porte une robe rouge"),
    ("We cook dinner together", "Nous cuisinons le dîner ensemble"),
    ("He drives a blue car", "Il conduit une voiture bleue"),
    ("They visit museums often", "Ils visitent souvent des musées"),
    ("The restaurant serves delicious food", "Le restaurant sert une délicieuse cuisine"),
    ("She studies mathematics at university", "Elle étudie les mathématiques à l'université"),
    ("We watch movies on Fridays", "Nous regardons des films le vendredi"),
    ("He listens to music while jogging", "Il écoute de la musique en faisant du jogging"),
    ("They travel around the world", "Ils voyagent autour du monde"),
    ("The book is on the table", "Le livre est sur la table"),
    ("She dances gracefully", "Elle danse avec grâce"),
    ("We celebrate birthdays with cake", "Nous célébrons les anniversaires avec un gâteau"),
    ("He works hard every day", "Il travaille dur tous les jours"),
    ("They speak different languages", "Ils parlent différentes langues"),
    ("The flowers bloom in spring", "Les fleurs fleurissent au printemps"),
    ("She writes poetry in her free time", "Elle écrit de la poésie pendant son temps libre"),
    ("We learn something new every day", "Nous apprenons quelque chose de nouveau chaque jour"),
    ("The dog barks loudly", "Le chien aboie bruyamment"),
    ("He sings beautifully", "Il chante magnifiquement"),
    ("They swim in the pool", "Ils nagent dans la piscine"),
    ("The birds chirp in the morning", "Les oiseaux gazouillent le matin"),
    ("She teaches English at school", "Elle enseigne l'anglais à l'école"),
    ("We eat breakfast together", "Nous prenons le petit déjeuner ensemble"),
    ("He paints landscapes", "Il peint des paysages"),
    ("They laugh at the joke", "Ils rient de la blague"),
    ("The clock ticks loudly", "L'horloge tic-tac bruyamment"),
    ("She runs in the park", "Elle court dans le parc"),
    ("We travel by train", "Nous voyageons en train"),
    ("He writes a letter", "Il écrit une lettre"),
    ("They read books at the library", "Ils lisent des livres à la bibliothèque"),
    ("The baby cries", "Le bébé pleure"),
    ("She studies hard for exams", "Elle étudie dur pour les examens"),
    ("We plant flowers in the garden", "Nous plantons des fleurs dans le jardin"),
    ("He fixes the car", "Il répare la voiture"),
    ("They drink coffee in the morning", "Ils boivent du café le matin"),
    ("The sun sets in the evening", "Le soleil se couche le soir"),
    ("She dances at the party", "Elle danse à la fête"),
    ("We play music at the concert", "Nous jouons de la musique au concert"),
    ("He cooks dinner for his family", "Il cuisine le dîner pour sa famille"),
    ("They study French grammar", "Ils étudient la grammaire française"),
    ("The rain falls gently", "La pluie tombe doucement"),
    ("She sings a song", "Elle chante une chanson"),
    ("We watch a movie together", "Nous regardons un film ensemble"),
    ("He sleeps deeply", "Il dort profondément"),
    ("They travel to Paris", "Ils voyagent à Paris"),
    ("The children play in the park", "Les enfants jouent dans le parc"),
    ("She walks along the beach", "Elle se promène le long de la plage"),
    ("We talk on the phone", "Nous parlons au téléphone"),
    ("He waits for the bus", "Il attend le bus"),
    ("They visit the Eiffel Tower", "Ils visitent la tour Eiffel"),
    ("The stars twinkle at night", "Les étoiles scintillent la nuit"),
    ("She dreams of flying", "Elle rêve de voler"),
    ("We work in the office", "Nous travaillons au bureau"),
    ("He studies history", "Il étudie l'histoire"),
    ("They listen to the radio", "Ils écoutent la radio"),
    ("The wind blows gently", "Le vent souffle doucement"),
    ("She swims in the ocean", "Elle nage dans l'océan"),
    ("We dance at the wedding", "Nous dansons au mariage"),
    ("He climbs the mountain", "Il gravit la montagne"),
    ("They hike in the forest", "Ils font de la randonnée dans la forêt"),
    ("The cat meows loudly", "Le chat miaule bruyamment"),
    ("She paints a picture", "Elle peint un tableau"),
    ("We build a sandcastle", "Nous construisons un château de sable"),
    ("He sings in the choir", "Il chante dans le chœur"),
    ("They ride bicycles", "Ils font du vélo"),
    ("The coffee is hot", "Le café est chaud"),
    ("She wears glasses", "Elle porte des lunettes"),
    ("We visit our grandparents", "Nous rendons visite à nos grands-parents"),
    ("He plays the guitar", "Il joue de la guitare"),
    ("They go shopping", "Ils font du shopping"),
    ("The teacher explains the lesson", "Le professeur explique la leçon"),
    ("She takes the train to work", "Elle prend le train pour aller au travail"),
    ("We bake cookies", "Nous faisons des biscuits"),
    ("He washes his hands", "Il se lave les mains"),
    ("They enjoy the sunset", "Ils apprécient le coucher du soleil"),
    ("The river flows calmly", "La rivière coule calmement"),
    ("She feeds the cat", "Elle nourrit le chat"),
    ("We visit the museum", "Nous visitons le musée"),
    ("He fixes his bicycle", "Il répare son vélo"),
    ("They paint the walls", "Ils peignent les murs"),
    ("The baby sleeps peacefully", "Le bébé dort paisiblement"),
    ("She ties her shoelaces", "Elle attache ses lacets"),
    ("We climb the stairs", "Nous montons les escaliers"),
    ("He shaves in the morning", "Il se rase le matin"),
    ("They set the table", "Ils mettent la table"),
    ("The airplane takes off", "L'avion décolle"),
    ("She waters the plants", "Elle arrose les plantes"),
    ("We practice yoga", "Nous pratiquons le yoga"),
    ("He turns off the light", "Il éteint la lumière"),
    ("They play video games", "Ils jouent aux jeux vidéo"),
    ("The soup smells delicious", "La soupe sent délicieusement bon"),
    ("She locks the door", "Elle ferme la porte à clé"),
    ("We enjoy a picnic", "Nous profitons d'un pique-nique"),
    ("He checks his email", "Il vérifie ses emails"),
    ("They go to the gym", "Ils vont à la salle de sport"),
    ("The moon shines brightly", "La lune brille intensément"),
    ("She catches the bus", "Elle attrape le bus"),
    ("We greet our neighbors", "Nous saluons nos voisins"),
    ("He combs his hair", "Il se peigne les cheveux"),
    ("They wave goodbye", "Ils font un signe d'adieu")

]

#######Swap for French-to-English
french_sentences, english_sentences = zip(*english_to_french)
english_sentences = ['<SOS> ' + sent + ' <EOS>' for sent in english_sentences]

########Tokenization
fr_tokenizer = Tokenizer()
fr_tokenizer.fit_on_texts(french_sentences)
fr_sequences = fr_tokenizer.texts_to_sequences(french_sentences)
fr_vocab_size = len(fr_tokenizer.word_index) + 1

eng_tokenizer = Tokenizer(filters='')
eng_tokenizer.fit_on_texts(english_sentences)
if '<SOS>' not in eng_tokenizer.word_index:
    eng_tokenizer.word_index['<SOS>'] = len(eng_tokenizer.word_index) + 1
if '<EOS>' not in eng_tokenizer.word_index:
    eng_tokenizer.word_index['<EOS>'] = len(eng_tokenizer.word_index) + 1
eng_sequences = eng_tokenizer.texts_to_sequences(english_sentences)
eng_vocab_size = len(eng_tokenizer.word_index) + 1

#########Padding sequences
max_fr_len = max(len(seq) for seq in fr_sequences)
max_eng_len = max(len(seq) for seq in eng_sequences)
fr_padded = pad_sequences(fr_sequences, maxlen=max_fr_len, padding='post')
eng_padded = pad_sequences(eng_sequences, maxlen=max_eng_len, padding='post')

#######Prepare decoder input and target data
decoder_input_data = eng_padded[:, :-1]
decoder_target_data = eng_padded[:, 1:]

########Model Parameters
embedding_dim = 256
units = 512

########Encoder
encoder_inputs = Input(shape=(max_fr_len,))
enc_embedding = Embedding(fr_vocab_size, embedding_dim)(encoder_inputs)
encoder_gru = GRU(units, return_sequences=True, return_state=True)
encoder_outputs, encoder_state = encoder_gru(enc_embedding)

#######Decoder
decoder_inputs = Input(shape=(max_eng_len - 1,))
dec_embedding = Embedding(eng_vocab_size, embedding_dim)(decoder_inputs)
decoder_gru = GRU(units, return_sequences=True, return_state=True)
decoder_outputs, _ = decoder_gru(dec_embedding, initial_state=encoder_state)
attention = Attention()
context = attention([decoder_outputs, encoder_outputs])
decoder_combined_context = Lambda(lambda x: tf.concat(x, axis=-1))([decoder_outputs, context])
decoder_dense = Dense(eng_vocab_size, activation='softmax')
decoder_outputs = decoder_dense(decoder_combined_context)

#######Define the model
model = Model([encoder_inputs, decoder_inputs], decoder_outputs)
model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])

########Train and evaluate
history = model.fit(
    [fr_padded, decoder_input_data],
    np.expand_dims(decoder_target_data, -1),
    batch_size=32,
    epochs=50,
    validation_data=([fr_padded, decoder_input_data], np.expand_dims(decoder_target_data, -1)),
    verbose=1
)

###########Report results
print("Training Loss (With Attention):", history.history['loss'][-1])
print("Validation Loss (With Attention):", history.history['val_loss'][-1])
print("Validation Accuracy (With Attention):", history.history['val_accuracy'][-1])

###############Inference Setup
encoder_model = Model(encoder_inputs, [encoder_outputs, encoder_state])

decoder_state_input = Input(shape=(units,))
decoder_inputs_single = Input(shape=(1,))  # Single timestep input
dec_embedding_single = Embedding(eng_vocab_size, embedding_dim)(decoder_inputs_single)
decoder_outputs_single, decoder_state = decoder_gru(dec_embedding_single, initial_state=decoder_state_input)
context_single = attention([decoder_outputs_single, encoder_outputs])
decoder_combined_context_single = Lambda(lambda x: tf.concat(x, axis=-1))([decoder_outputs_single, context_single])
decoder_outputs_single = decoder_dense(decoder_combined_context_single)
decoder_model = Model(
    [decoder_inputs_single, decoder_state_input, encoder_outputs],
    [decoder_outputs_single, decoder_state]
)

########Fixed Translation Function
def translate(sentence):
    seq = fr_tokenizer.texts_to_sequences([sentence])
    seq = pad_sequences(seq, maxlen=max_fr_len, padding='post')
    enc_outputs, state = encoder_model.predict(seq, verbose=0)

    target_seq = np.array([[eng_tokenizer.word_index['<SOS>']]])
    output_sentence = []

    for _ in range(max_eng_len):
        output_tokens, state = decoder_model.predict([target_seq, state, enc_outputs], verbose=0)
        sampled_token_index = np.argmax(output_tokens[0, 0, :])  # Adjusted index for single timestep
        sampled_word = eng_tokenizer.index_word.get(sampled_token_index, '')

        if sampled_word == '<EOS>' or sampled_word == '':
            break
        output_sentence.append(sampled_word)
        target_seq = np.array([[sampled_token_index]])

    return ' '.join(output_sentence)

########Qualitative Validation
test_sentences = [
    "J'ai froid",
    "Elle est heureuse",
    "Nous aimons la musique",
    "Il conduit une voiture bleue",
    "Le soleil brille"
]

print("\nQualitative Validation (With Attention):")
for sent in test_sentences:
    translation = translate(sent)
    print(f"French: {sent} -> English: {translation}")

tf.config.run_functions_eagerly(False)
# Out:
# Epoch 1/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 4s 1s/step - accuracy: 0.2244 - loss: 5.5184 - val_accuracy: 0.4239 - val_loss: 4.8839
# Epoch 2/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 3s 930ms/step - accuracy: 0.4307 - loss: 4.4044 - val_accuracy: 0.4239 - val_loss: 3.4746
# Epoch 3/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 3s 915ms/step - accuracy: 0.4305 - loss: 3.2419 - val_accuracy: 0.4239 - val_loss: 3.0577
# Epoch 4/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 3s 936ms/step - accuracy: 0.4223 - loss: 3.0002 - val_accuracy: 0.4239 - val_loss: 2.7419
# Epoch 5/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 5s 742ms/step - accuracy: 0.4349 - loss: 2.7725 - val_accuracy: 0.5239 - val_loss: 2.6747
# Epoch 6/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 3s 919ms/step - accuracy: 0.5267 - loss: 2.6547 - val_accuracy: 0.5257 - val_loss: 2.5903
# Epoch 7/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 5s 915ms/step - accuracy: 0.5247 - loss: 2.5965 - val_accuracy: 0.5487 - val_loss: 2.5079
# Epoch 8/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 5s 739ms/step - accuracy: 0.5438 - loss: 2.5284 - val_accuracy: 0.5469 - val_loss: 2.4430
# Epoch 9/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 6s 927ms/step - accuracy: 0.5389 - loss: 2.4521 - val_accuracy: 0.5487 - val_loss: 2.3753
# Epoch 10/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 4s 1s/step - accuracy: 0.5535 - loss: 2.3432 - val_accuracy: 0.5442 - val_loss: 2.3188
# Epoch 11/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 3s 935ms/step - accuracy: 0.5449 - loss: 2.3121 - val_accuracy: 0.5531 - val_loss: 2.2498
# Epoch 12/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 3s 931ms/step - accuracy: 0.5623 - loss: 2.1724 - val_accuracy: 0.5496 - val_loss: 2.1886
# Epoch 13/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 3s 925ms/step - accuracy: 0.5520 - loss: 2.1664 - val_accuracy: 0.5513 - val_loss: 2.1365
# Epoch 14/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 4s 959ms/step - accuracy: 0.5487 - loss: 2.1417 - val_accuracy: 0.5593 - val_loss: 2.0753
# Epoch 15/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 3s 932ms/step - accuracy: 0.5663 - loss: 2.0401 - val_accuracy: 0.5619 - val_loss: 2.0331
# Epoch 16/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 5s 929ms/step - accuracy: 0.5678 - loss: 1.9908 - val_accuracy: 0.5664 - val_loss: 1.9766
# Epoch 17/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 5s 923ms/step - accuracy: 0.5664 - loss: 1.9835 - val_accuracy: 0.5655 - val_loss: 1.9331
# Epoch 18/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 3s 908ms/step - accuracy: 0.5667 - loss: 1.9252 - val_accuracy: 0.5664 - val_loss: 1.8849
# Epoch 19/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 3s 917ms/step - accuracy: 0.5680 - loss: 1.8701 - val_accuracy: 0.5619 - val_loss: 1.8482
# Epoch 20/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 5s 908ms/step - accuracy: 0.5650 - loss: 1.8435 - val_accuracy: 0.5894 - val_loss: 1.7990
# Epoch 21/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 3s 908ms/step - accuracy: 0.5792 - loss: 1.8171 - val_accuracy: 0.5805 - val_loss: 1.7872
# Epoch 22/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 5s 1s/step - accuracy: 0.5808 - loss: 1.7774 - val_accuracy: 0.5858 - val_loss: 1.7425
# Epoch 23/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 5s 912ms/step - accuracy: 0.5884 - loss: 1.7339 - val_accuracy: 0.5876 - val_loss: 1.7047
# Epoch 24/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 3s 918ms/step - accuracy: 0.5754 - loss: 1.7458 - val_accuracy: 0.6027 - val_loss: 1.7063
# Epoch 25/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 4s 1s/step - accuracy: 0.5971 - loss: 1.6832 - val_accuracy: 0.5823 - val_loss: 1.6630
# Epoch 26/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 3s